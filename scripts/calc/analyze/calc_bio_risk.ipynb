# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import rasterio as rio
import rioxarray as rxr
import geopandas as gpd
from rasterio.enums import Resampling

# %%
clcd_frame = xr.open_dataset("/home/zyzh0/coding/risk_evaluation/scripts/outputs/CLCD/CLCD_v01_2015.nc")

# %%
clcd_frame.rio.write_crs("EPSG:4326", inplace=True)
# Out:
# <xarray.Dataset>
# Dimensions:                        (y: 55661, x: 48240)
# Coordinates:
#   * y                              (y) float64 43.0 43.0 43.0 ... 28.0 28.0 28.0
#   * x                              (x) float64 110.0 110.0 110.0 ... 123.0 123.0
#     spatial_ref                    int64 0
# Data variables:
#     __xarray_dataarray_variable__  (y, x) float64 ...

# %%
# Bad resampling method
frame_resampled = clcd_frame.rio.reproject("EPSG:4326", shape=(1800, 1560), resampling=Resampling.mode)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 frame_resampled=clcd_frame.rio.reproject(clcd_frame.rio.crs,shape=(1800,1560),resampling=rio.enums.Resampling.mode)
#
# File ~/anaconda3/envs/gis/lib/python3.10/site-packages/rioxarray/raster_dataset.py:121, in RasterDataset.reproject(self, dst_crs, resolution, shape, transform, resampling, nodata, **kwargs)
#     118 try:
#     119     x_dim, y_dim = _get_spatial_dims(self._obj, var)
#     120     resampled_dataset[var] = (
# --> 121         self._obj[var]
#     122         .rio.set_spatial_dims(x_dim=x_dim, y_dim=y_dim, inplace=True)
#     123         .rio.reproject(
#     124             dst_crs,
#     125             resolution=resolution,
#     126             shape=shape,
#     127             transform=transform,
#     128             resampling=resampling,
#     129             nodata=nodata,
# ...

# %%
sf = frame_resampled
fig,ax = plt.subplots(figsize=(10,10))
sf.__xarray_dataarray_variable__.plot(ax=ax, cmap='Paired')
ax.set_xlabel('$^\circ E$')
ax.set_ylabel('$^\circ N$')
